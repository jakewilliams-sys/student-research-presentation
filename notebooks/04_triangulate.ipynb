# %% [markdown]
# # 04 - Triangulation (Agent 2)
#
# Cross-reference all coded data across participants for segment comparisons and pattern detection.
#
# **Output:** `data/processed/triangulated_data/triangulated_results.json`

# %%
import sys, json, logging
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s: %(message)s')

from src.pipeline.orchestrator import PipelineOrchestrator

# %%
orch = PipelineOrchestrator()

results = orch.run_agent('triangulation')
print(json.dumps(results, indent=2, default=str))

# %% [markdown]
# ## Review Triangulation Results

# %%
from src.agents.triangulation_agent import load_triangulated

triang = load_triangulated()
if triang:
    print(f"Summary:\n{triang.get('summary', '')}")
    print(f"\nComparisons: {len(triang.get('segment_comparisons', []))}")
    print(f"Patterns: {len(triang.get('patterns', []))}")
    print(f"Say-Do Gaps: {len(triang.get('say_do_gaps', []))}")
    
    for p in triang.get('patterns', [])[:5]:
        if isinstance(p, dict):
            print(f"  [{p.get('pattern_type', '')}] {p.get('pattern', '')}")
else:
    print('No triangulated data found')
