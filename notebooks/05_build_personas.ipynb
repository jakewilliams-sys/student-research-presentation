# %% [markdown]
# # 05 - Build Personas (Agent 3)
#
# Cluster participants into behavioural archetypes and map their ordering journeys.
#
# **Output:** `data/processed/personas/personas.json`
#
# **Human Checkpoint:** Review persona groupings before insight generation.

# %%
import sys, json, logging
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s: %(message)s')

from src.pipeline.orchestrator import PipelineOrchestrator

# %%
orch = PipelineOrchestrator()

results = orch.run_agent('persona')
print(json.dumps(results, indent=2, default=str))

# %% [markdown]
# ## Review Personas

# %%
from src.agents.persona_agent import load_personas

personas = load_personas()
if personas:
    for p in personas.get('personas', []):
        if isinstance(p, dict):
            print(f"\n{'='*50}")
            print(f"{p.get('name', '')} (n={p.get('size', '?')})")
            print(f"{p.get('tagline', '')}")
            print(f"{'='*50}")
            print(f"Distribution: {p.get('segment_distribution', {})}")
            for c in p.get('key_characteristics', []):
                print(f"  - {c}")
            print(f"\nParticipants: {', '.join(p.get('participants', []))}")

# %% [markdown]
# ## Human Checkpoint 2
#
# Review the persona groupings:
# - Do the clusters make sense behaviourally?
# - Are any participants misplaced?
# - Are there enough participants per persona (minimum 4)?
#
# When satisfied, approve:

# %%
orch.approve_checkpoint('persona', notes='Persona groupings reviewed and approved')
